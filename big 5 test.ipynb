# %%
def big_five_personality_test():
    questions = {
        "Openness": [
            "I am someone who is always full of new ideas.",
            "I am quick to understand new things.",
            "I have high appreciation for art, culture, and literature.",
            "I am interested in abstract ideas.",
            "I am imaginative and creative."
        ],
        "Conscientiousness": [
            "I am organized and pay attention to details.",
            "I am diligent and complete tasks on time.",
            "I am reliable.",
            "I am NOT spontaneous.",
            "I am careful and cautious."
        ],
        "Extraversion": [
            "I am outgoing and sociable.",
            "I am talkative.",
            "I am energetic and enthusiastic.",
            "I take charge of projects and exhibit good leadership skills.",
            "I am not afraid of speaking in front of crowds."
        ],
        "Agreeableness": [
            "I am considerate and kind to others.",
            "I am competitive and like to win.",
            "I am cooperative and easy to get along with.",
            "I am respectful and not judgmental.",
            "I trust people easily."
        ],
        "Neuroticism": [
            "I get stressed out easily.",
            "I am anxious and worry a lot.",
            "I get nervous easily.",
            "I often have negative thoughts.",
            "I am moody and experience frequent mood swings."
        ]
    }

    scores = {
        "Openness": 0,
        "Conscientiousness": 0,
        "Extraversion": 0,
        "Agreeableness": 0,
        "Neuroticism": 0
    }

    print("Welcome to the Big Five Personality Test!")
    print("Please rate each statement on a scale of 1 to 5, where 1 is strongly disagree and 5 is strongly agree.")

    for trait, trait_questions in questions.items():
        print("\nTrait:", trait)
        for i, question in enumerate(trait_questions):
            print("Question", i + 1, ":", question)
            while True:
                try:
                    answer = int(input("Enter your answer (1-5): "))
                    if answer < 1 or answer > 5:
                        raise ValueError
                    break
                except ValueError:
                    print("Invalid input. Please enter a number between 1 and 5.")

            scores[trait] += answer

    print("\nResults:")
    for trait, score in scores.items():
        max_score = 25
        percentage = convert_to_percentage(score, max_score)
        print(f"{trait}: {percentage}%")

def convert_to_percentage(score, max_score):
    """Converts a score to a percentage based on the given range."""
    percentage = (score) / (max_score) * 100
    return percentage

big_five_personality_test()
# Out:
# Welcome to the Big Five Personality Test!
# Please rate each statement on a scale of 1 to 5, where 1 is strongly disagree and 5 is strongly agree.
#
# Trait: Openness
# Question 1 : I am someone who is always full of new ideas.
# Enter your answer (1-5): 1
# Question 2 : I am quick to understand new things.
# Enter your answer (1-5): 2
# Question 3 : I have high appreciation for art, culture, and literature.
# Enter your answer (1-5): 3
# Question 4 : I am interested in abstract ideas.
# Enter your answer (1-5): 2
# Question 5 : I am imaginative and creative.
# Enter your answer (1-5): 3
#
# Trait: Conscientiousness
# Question 1 : I am organized and pay attention to details.
# Enter your answer (1-5): 1
# Question 2 : I am diligent and complete tasks on time.
# Enter your answer (1-5): 2
# Question 3 : I am reliable.
# Enter your answer (1-5): 3
# Question 4 : I am NOT spontaneous.
# Enter your answer (1-5): 2
# Question 5 : I am careful and cautious.
# Enter your answer (1-5): 1
#
# Trait: Extraversion
# Question 1 : I am outgoing and sociable.
# Enter your answer (1-5): 2
# Question 2 : I am talkative.
# Enter your answer (1-5): 3
# Question 3 : I am energetic and enthusiastic.
# Enter your answer (1-5): 2
# Question 4 : I take charge of projects and exhibit good leadership skills.
# Enter your answer (1-5): 1
# Question 5 : I am not afraid of speaking in front of crowds.
# Enter your answer (1-5): 5
#
# Trait: Agreeableness
# Question 1 : I am considerate and kind to others.
# Enter your answer (1-5): 3
# Question 2 : I am competitive and like to win.
# Enter your answer (1-5): 4
# Question 3 : I am cooperative and easy to get along with.
# Enter your answer (1-5): 2
# Question 4 : I am respectful and not judgmental.
# Enter your answer (1-5): 3
# Question 5 : I trust people easily.
# Enter your answer (1-5): 4
#
# Trait: Neuroticism
# Question 1 : I get stressed out easily.
# Enter your answer (1-5):
# Invalid input. Please enter a number between 1 and 5.
# Enter your answer (1-5): 2
# Question 2 : I am anxious and worry a lot.
# Enter your answer (1-5): 3
# Question 3 : I get nervous easily.
# Enter your answer (1-5): 4
# Question 4 : I often have negative thoughts.
# Enter your answer (1-5): 1
# Question 5 : I am moody and experience frequent mood swings.
# Enter your answer (1-5): 2
#
# Results:
# Openness: 44.0%
# Conscientiousness: 36.0%
# Extraversion: 52.0%
# Agreeableness: 64.0%
# Neuroticism: 48.0%
